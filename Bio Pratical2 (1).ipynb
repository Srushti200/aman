# %%
pip install pydeseq2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydeseq2 in c:\users\syeol\appdata\roaming\python\python313\site-packages (0.5.2)
# Requirement already satisfied: anndata>=0.11.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from pydeseq2) (0.12.2)
# Requirement already satisfied: formulaic>=1.0.2 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from pydeseq2) (1.2.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from pydeseq2) (2.1.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from pydeseq2) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from pydeseq2) (1.5.2)
# Requirement already satisfied: scipy>=1.11.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from pydeseq2) (1.14.1)
# Requirement already satisfied: formulaic-contrasts>=0.2.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from pydeseq2) (1.0.0)
# Requirement already satisfied: matplotlib>=3.6.2 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from pydeseq2) (3.10.1)
# Requirement already satisfied: array-api-compat>=1.7.1 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from anndata>=0.11.0->pydeseq2) (1.12.0)
# Requirement already satisfied: h5py>=3.8 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from anndata>=0.11.0->pydeseq2) (3.14.0)
# Requirement already satisfied: legacy-api-wrap in c:\users\syeol\appdata\roaming\python\python313\site-packages (from anndata>=0.11.0->pydeseq2) (1.4.1)
# Requirement already satisfied: natsort in c:\users\syeol\appdata\roaming\python\python313\site-packages (from anndata>=0.11.0->pydeseq2) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from anndata>=0.11.0->pydeseq2) (24.2)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from anndata>=0.11.0->pydeseq2) (3.1.2)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from formulaic>=1.0.2->pydeseq2) (1.3.0)
# Requirement already satisfied: narwhals>=1.17 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from formulaic>=1.0.2->pydeseq2) (1.47.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from formulaic>=1.0.2->pydeseq2) (4.12.2)
# Requirement already satisfied: wrapt>=1.17.0rc1 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from formulaic>=1.0.2->pydeseq2) (2.0.0rc2)
# Requirement already satisfied: session-info in c:\users\syeol\appdata\roaming\python\python313\site-packages (from formulaic-contrasts>=0.2.0->pydeseq2) (1.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6.2->pydeseq2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6.2->pydeseq2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6.2->pydeseq2) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6.2->pydeseq2) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6.2->pydeseq2) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6.2->pydeseq2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6.2->pydeseq2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from pandas>=1.4.0->pydeseq2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from pandas>=1.4.0->pydeseq2) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->pydeseq2) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.1.0->pydeseq2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.1.0->pydeseq2) (3.5.0)
# Requirement already satisfied: donfig>=0.8 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (0.16.2)
# Requirement already satisfied: pyyaml in c:\users\syeol\appdata\roaming\python\python313\site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (6.0.2)
# Requirement already satisfied: crc32c>=2.7 in c:\users\syeol\appdata\roaming\python\python313\site-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (2.7.1)
# Requirement already satisfied: stdlib_list in c:\users\syeol\appdata\roaming\python\python313\site-packages (from session-info->formulaic-contrasts>=0.2.0->pydeseq2) (0.11.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pydeseq2.utils import load_example_data
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

import warnings
warnings.filterwarnings("ignore")

counts_df = load_example_data()

conditions = ['Control'] * (counts_df.shape[1] // 2) + ['Treatment'] * (counts_df.shape[1] // 2)
metadata_df = pd.DataFrame({'condition': conditions}, index=counts_df.columns)

print("Initial Data (first 5 rows):")
print(counts_df.head())


counts_t = counts_df.T


dds = DeseqDataSet(
    counts=counts_t,
    metadata=metadata_df,
    design_factors="condition"
)


dds.deseq2()


stat_res = DeseqStats(dds, contrast=("condition", "Treatment", "Control"))
stat_res.summary()
results_df = stat_res.results_df

print("\nDifferential Expression Results (first 10 rows):")
print(results_df.head(10))


plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=results_df,
    x="log2FoldChange",
    y=-np.log10(results_df["pvalue"]),
    hue= results_df["padj"] <  0.05
)
plt.axhline(y=-np.log10(0.05), color="red", linestyle="--", label="P-value = 0.05")
plt.xlabel("Log2 Fold Change")
plt.ylabel("-log10(P-value)")
plt.title("Volcano Plot of Differential Gene Expression")
plt.legend()
plt.show()
# Out:
# Initial Data (first 5 rows):
#          gene1  gene2  gene3  gene4  gene5  gene6  gene7  gene8  gene9  gene10
# sample1     12     21      4    130     18      0     16     54     49       3
# sample2      1     44      2     63     11     10     70     32     57       9
# sample3      4      4     11    180     21      3     28     34     65       2
# sample4      1     10      2    100     44      9     28     16     33       9
# sample5      1     11      6    135     16      2     32     29     31       5
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting size factors...
# ... done in 0.00 seconds.
#
# Fitting dispersions...
# ... done in 0.14 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.02 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.16 seconds.
#
# Fitting LFCs...
# ... done in 0.17 seconds.
#
# Calculating cook's distance...
# ... done in 0.02 seconds.
#
# Replacing 0 outlier genes.
#
# Running Wald tests...
# ... done in 0.17 seconds.
# Log2 fold change & Wald test p-value: condition Treatment vs Control
#             baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# sample1    15.948319       -0.593868  0.598062 -0.992987  0.320716  0.992720
# sample2    20.071993        0.862193  0.635643  1.356412  0.174968  0.878444
# sample3    17.982042       -0.403888  0.658829 -0.613038  0.539851  0.992720
# sample4    15.513719        0.152065  0.623002  0.244084  0.807166  0.992720
# sample5    13.329567       -0.154633  0.576663 -0.268152  0.788582  0.992720
# ...              ...             ...       ...       ...       ...       ...
# sample96   15.487539        0.260864  0.589902  0.442216  0.658333  0.992720
# sample97   12.889048       -0.036935  0.569008 -0.064911  0.948245  0.992720
# sample98   16.679672       -0.037144  0.633230 -0.058658  0.953225  0.992720
# sample99   24.093650       -0.016231  0.600110 -0.027047  0.978422  0.992720
# sample100  20.405656        0.374718  0.674120  0.555863  0.578305  0.992720
#
# [100 rows x 6 columns]
#
# Differential Expression Results (first 10 rows):
#            baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# sample1   15.948319       -0.593868  0.598062 -0.992987  0.320716  0.992720
# sample2   20.071993        0.862193  0.635643  1.356412  0.174968  0.878444
# sample3   17.982042       -0.403888  0.658829 -0.613038  0.539851  0.992720
# sample4   15.513719        0.152065  0.623002  0.244084  0.807166  0.992720
# sample5   13.329567       -0.154633  0.576663 -0.268152  0.788582  0.992720
# sample6   14.040585        1.235591  0.605532  2.040507  0.041300  0.701708
# sample7   24.995795        0.107964  0.761155  0.141842  0.887205  0.992720
# sample8   20.279220        0.423860  0.593330  0.714376  0.474995  0.992720
# sample9   14.180884       -0.364810  0.618899 -0.589449  0.555560  0.992720
# sample10  21.608171       -0.765549  0.573464 -1.334954  0.181891  0.878444
